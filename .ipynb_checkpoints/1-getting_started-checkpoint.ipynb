# %% [markdown]
# ## 安装

# %% [markdown]
# Python官网：https://www.python.org/
#
# 推荐安装：
# 1. Python 3.69
# 2. Python 3.79
#
# 不建议安装最新版本的Python，因为有一些第三方库并不能够支持最新版本的Python。#

# %% [markdown]
# ## 检查Python版本

# %% [markdown]
# 这是Linux系统之下对Python版本的检测：
#
# ![image.png](attachment:c74caf60-cdfd-463a-8ba0-5af1dba274a2.png)
#
# 或者我们可以直接进入Python3的开发环境：
#
# ![image.png](attachment:72f824dc-db6f-45f6-b165-d02ba373bc93.png)

# %% [markdown]
# ## 编译器

# %% [markdown]
# Python语言有自带的IDE，如下图：
#
# ![image.png](attachment:31715c9a-49c1-4115-b35c-6bd795db592c.png)
#
# 但是不推荐使用这个IDE来进行开发。
